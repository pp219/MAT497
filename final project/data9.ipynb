# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plot = pd.read_excel('data9.xlsx')

# %%
x=plot['x']
y=plot['y']
z=plot['z']
plot.head()
# Out:
#           x         y         z
# 0  0.683152  0.051699  0.000978
# 1  0.683149  0.051792  0.000981
# 2  0.683056  0.051746  0.000982
# 3  0.683146  0.051863  0.000982
# 4  0.682972  0.051787  0.000986

# %%
grid_x, grid_y = np.meshgrid(np.linspace(x.min(), x.max(),
                                         np.int(np.floor(10000*(x.max()-x.min())))),
                             np.linspace(y.min(), y.max(),
                                         np.int(np.floor(10000*(y.max()-y.min())))))

# %%
from scipy.interpolate import griddata
data = griddata((x,y),z,(grid_x,grid_y), method='cubic')

# %%
plt.imshow(data, extent=[x.min(), x.max(),y.min(), y.max()])

# %%
plt.scatter(x,y,c='k',s=.2)
