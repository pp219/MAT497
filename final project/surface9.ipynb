# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plot = pd.read_excel('surface9.xlsx')

# %%
x=plot['x']
y=plot['y']
z=plot['z']
plot.head()
# Out:
#           x         y         z
# 0  0.021239  0.031213  0.000002
# 1  0.023144  0.030096  0.000003
# 2  0.021246  0.031456  0.000002
# 3  0.021705  0.031453  0.000003
# 4  0.021258  0.031876  0.000002

# %%
grid_x, grid_y = np.meshgrid(np.linspace(x.min(), x.max(),
                                         np.int(np.floor(10000*(x.max()-x.min())))),
                             np.linspace(y.min(), y.max(),
                                         np.int(np.floor(10000*(y.max()-y.min())))))

# %%
from scipy.interpolate import griddata
data = griddata((x,y),z,(grid_x,grid_y), method='cubic')

# %%
plt.imshow(data, extent=[x.min(), x.max(),y.min(), y.max()])

# %%
plt.scatter(x,y,c='k',s=.2)
