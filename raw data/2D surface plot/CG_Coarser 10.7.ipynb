# %%
import pandas as pd

# %%
dfs = pd.read_csv('CG_Coarser.csv')

# %%
dfs.head()
# Out:
#           x         y         z
# 0  0.045903  0.025959  0.000011
# 1  0.042561  0.040035  0.000019
# 2  0.031704  0.034908  0.000016
# 3  0.034966  0.013827  0.000003
# 4  0.039560  0.009104  0.000000

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt

fig = plt.figure()
ax1 = fig.add_subplot(111, projection = '3d')

ax1.plot(dfs['X'],dfs['Y'],dfs['Color'])

ax1.set_xlabel('X Axis')
ax1.set_ylabel('Y Axis')
ax1.set_zlabel('Z Axis')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.image import NonUniformImage
from matplotlib import cm

a = dfs['X]'

b = dfs['Y']

c = dfs['Color']

interp = 'bilinear'

ax = axs[1, 0]
im = NonUniformImage(ax, interpolation=interp, extent=(-4, 4, -4, 4),
                     cmap=cm.Purples)
im.set_data(x, y, z)
ax.images.append(im)
ax.set_xlim(-4, 4)
ax.set_ylim(-4, 4)
ax.set_title(interp)
        
plt.show()
# Out:
#   File "<ipython-input-1-84097c7e7431>", line 8
#     b = dfs['Y']
#     ^
# SyntaxError: invalid syntax
